# %% [markdown]
# <a href="https://colab.research.google.com/github/Luckyaman/Fake-Base-Station/blob/main/PMFLOSNLOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Simulate reconstruction errors for normal and anomalous instances
num_normal = 524217  # Number of normal instances
num_anomalous = 1960  # Number of anomalous instances

# Normal instances around mean 0.5, small std deviation
normal_errors = np.random.normal(0.5, 0.1, num_normal)

# Anomalous instances around mean 1.5, larger std deviation
anomalous_errors = np.random.normal(1.25, 0.2, num_anomalous)

# Combine and label the data
reconstruction_errors = np.concatenate([normal_errors, anomalous_errors])
true_labels = np.array([0] * num_normal + [1] * num_anomalous)  # 0 for Normal, 1 for Anomalous

# Calculate the mean and std deviation of reconstruction errors
mean_error = np.mean(reconstruction_errors)
std_error = np.std(reconstruction_errors)

# Calculate Z-scores for all reconstruction errors
z_scores = (reconstruction_errors - mean_error) / std_error

# Set a Z-score threshold
z_threshold = 3.20

# Classify based on Z-score threshold
predicted_labels = np.where(np.abs(z_scores) > z_threshold, 1, 0)  # 1 for Anomaly, 0 for Normal


# Plot the histogram for empirical PMF
plt.figure(figsize=(10, 6))
plt.hist(reconstruction_errors, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7, label='Empirical PMF')

# Overlay fitted normal distributions for each class
x = np.linspace(min(reconstruction_errors), max(reconstruction_errors), 1000)

# Highlight threshold regions
plt.axvline(mean_error + z_threshold * std_error, color='orange', linestyle='--', label='Anomaly Threshold=0.85')
#plt.axvline(mean_error - z_threshold * std_error, color='orange', linestyle='--')

# Customize plot
plt.xlabel('Reconstruction Error',fontsize=14)
plt.ylabel('Probability Density',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(fontsize=14)
plt.grid(True)

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Simulate reconstruction errors for normal and anomalous instances
num_normal = 524217  # Number of normal instances
num_anomalous = 1960  # Number of anomalous instances

# Normal instances around mean 0.5, small std deviation
normal_errors = np.random.normal(0.53, 0.11, num_normal)

# Anomalous instances around mean 1.5, larger std deviation
anomalous_errors = np.random.normal(1.30, 0.25, num_anomalous)

# Combine and label the data
reconstruction_errors = np.concatenate([normal_errors, anomalous_errors])
true_labels = np.array([0] * num_normal + [1] * num_anomalous)  # 0 for Normal, 1 for Anomalous

# Calculate the mean and std deviation of reconstruction errors
mean_error = np.mean(reconstruction_errors)
std_error = np.std(reconstruction_errors)

# Calculate Z-scores for all reconstruction errors
z_scores = (reconstruction_errors - mean_error) / std_error

# Set a Z-score threshold
z_threshold = 3.25

# Classify based on Z-score threshold
predicted_labels = np.where(np.abs(z_scores) > z_threshold, 1, 0)  # 1 for Anomaly, 0 for Normal


# Plot the histogram for empirical PMF
plt.figure(figsize=(10, 6))
plt.hist(reconstruction_errors, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7, label='Empirical PMF')

# Overlay fitted normal distributions for each class
x = np.linspace(min(reconstruction_errors), max(reconstruction_errors), 1000)

# Highlight threshold regions
plt.axvline(mean_error + z_threshold * std_error, color='orange', linestyle='--', label='Anomaly Threshold=0.90')
#plt.axvline(mean_error - z_threshold * std_error, color='orange', linestyle='--')
# Adjust x-axis range to replicate the curve's characteristics
plt.xlim(0, 2.0)

# Customize plot
plt.xlabel('Reconstruction Error',fontsize=14)
plt.ylabel('Probability Density',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(fontsize=14)
plt.grid(True)

# Show plot
plt.show()
